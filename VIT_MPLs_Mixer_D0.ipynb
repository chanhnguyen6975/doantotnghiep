# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -r '/content/drive/MyDrive/Projects/vit-d0/requirements.txt'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.1 MB 8.3 MB/s
# ...

# %%
# !python '/content/drive/MyDrive/Projects/vit-d0/train.py' \
 --train-folder '/content/drive/MyDrive/D0/train' \
 --valid-folder '/content/drive/MyDrive/D0/val' \
 --num-classes 40 \
 --image-size 224 \
 --patch-size 8 \
 --lr 0.0001 \
 --epochs 40 \
 --num-heads 12 \
 --model-folder '/content/drive/MyDrive/AI/VIT'
# Out:
# 2022-12-04 11:23:59.428419: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ---------------------Welcome to ProtonX MLP Mixer-------------------
# Github: bangoc123 and tiena2cva
# Email: protonxai@gmail.com
# ---------------------------------------------------------------------
# Training Vit Transformer model with hyper-params:
# ...
# 0.model: custom
# 1.num_classes: 40
# 2.patch_size: 8
# 3.num_heads: 12
# 4.att_size: 64
# 5.num_layer: 2
# 6.mlp_size: 128
# 7.lr: 0.0001
# 8.weight_decay: 0.0001
# 9.batch_size: 32
# 10.epochs: 40
# 11.image_size: 224
# 12.image_channels: 3
# 13.train_folder: /content/drive/MyDrive/D0/train
# 14.valid_folder: /content/drive/MyDrive/D0/val
# 15.model_folder: /content/drive/MyDrive/AI/VIT
# ...
# Found 3138 files belonging to 40 classes.
# ...

# %%
# !python '/content/drive/MyDrive/Projects/mlp-mixer-d0/train.py' --epochs 40 --num-classes 40 \
 --train-folder '/content/drive/MyDrive/D0/train' \
 --valid-folder '/content/drive/MyDrive/D0/val' \
 --image-size 224 \
 --patch-size 8 \
 --model-folder '/content/drive/MyDrive/AI/Mixer'
# Out:
# 2022-12-04 11:31:29.280143: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ---------------------Welcome to ProtonX MLP Mixer-------------------
# Github: bangoc123
# Email: protonxai@gmail.com
# ---------------------------------------------------------------------
# Training MLP-Mixer model with hyper-params:
# ...
# 0.logdir: logs
# 1.train_folder: /content/drive/MyDrive/D0/train
# 2.valid_folder: /content/drive/MyDrive/D0/val
# 3.model_folder: /content/drive/MyDrive/AI/Mixer
# 4.num_classes: 40
# 5.batch_size: 32
# 6.epochs: 10
# 7.dc: 2048
# 8.ds: 256
# 9.c: 512
# 10.image_size: 224
# 11.patch_size: 8
# 12.num_of_mlp_blocks: 8
# 13.learning_rate: 0.001
# 14.validation_split: 0.2
# 15.image_channels: 3
# ...
# Found 3138 files belonging to 40 classes.
# ...

# %%
# !python '/content/drive/MyDrive/Projects/vit-d0/train.py' \
 --train-folder '/content/drive/MyDrive/AI/classification/train' \
 --valid-folder '/content/drive/MyDrive/AI/classification/val' \
 --num-classes 102 \
 --image-size 224 \
 --patch-size 8 \
 --lr 0.0001 \
 --epochs 40 \
 --num-heads 12 \
 --model-folder '/content/drive/MyDrive/AI/VIT/IP102'
# Out:
# 2022-12-05 08:33:34.215954: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# ---------------------Welcome to ProtonX MLP Mixer-------------------
# Github: bangoc123 and tiena2cva
# Email: protonxai@gmail.com
# ---------------------------------------------------------------------
# Training Vit Transformer model with hyper-params:
# ...
# 0.model: custom
# 1.num_classes: 102
# 2.patch_size: 8
# 3.num_heads: 12
# 4.att_size: 64
# 5.num_layer: 2
# 6.mlp_size: 128
# 7.lr: 0.0001
# 8.weight_decay: 0.0001
# 9.batch_size: 32
# 10.epochs: 40
# 11.image_size: 224
# 12.image_channels: 3
# 13.train_folder: /content/drive/MyDrive/AI/classification/train
# 14.valid_folder: /content/drive/MyDrive/AI/classification/val
# 15.model_folder: /content/drive/MyDrive/AI/VIT/IP102
# ...
